# %% [markdown]
# # Introduction to the Data Sets

# %% [markdown]
# > Written by Dr Daniel Buscombe, Northern Arizona University
#
# > Part of a series of notebooks for image recognition and classification using deep convolutional neural networks

# %% [markdown]
# The data sets provided are hosting within an Amazon Web Services S3 bucket

# %%
import s3fs
fs = s3fs.S3FileSystem(anon=True)
fs.ls('cdi-workshop')
# Out:
# ['cdi-workshop/fully_conv_semseg',
#  'cdi-workshop/imrecog_data',
#  'cdi-workshop/semseg_data']

# %% [markdown]
# ## Looking at file structure

# %% [markdown]
# There are two major subdirectories:
# * 'imrecog_data': contains example data sets for image recognition
# * 'semseg_data': contains example data sets for semantic segmentation

# %%
fs.ls('cdi-workshop/imrecog_data')
# Out:
# ['cdi-workshop/imrecog_data/EuroSAT',
#  'cdi-workshop/imrecog_data/Imagenet',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45',
#  'cdi-workshop/imrecog_data/UCMerced_LandUse',
#  'cdi-workshop/imrecog_data/plankton']

# %%
fs.ls('cdi-workshop/semseg_data')
# Out:
# ['cdi-workshop/semseg_data/Monterey_scarps',
#  'cdi-workshop/semseg_data/RC1671L',
#  'cdi-workshop/semseg_data/Zurich_dataset_v1.0',
#  'cdi-workshop/semseg_data/ccr',
#  'cdi-workshop/semseg_data/gc',
#  'cdi-workshop/semseg_data/nwpu',
#  'cdi-workshop/semseg_data/ontario',
#  'cdi-workshop/semseg_data/sandbars',
#  'cdi-workshop/semseg_data/seabright']

# %%
len(fs.ls('cdi-workshop/semseg_data/gc/train'))
# Out:
# 16

# %%
fs.ls('cdi-workshop/imrecog_data/NWPU-RESISC45/test/')
# Out:
# ['cdi-workshop/imrecog_data/NWPU-RESISC45/test/airplane',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/airport',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/baseball_diamond',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/basketball_court',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/beach',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/bridge',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/chaparral',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/church',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/circular_farmland',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/cloud',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/commercial_area',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/dense_residential',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/desert',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/forest',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/freeway',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/golf_course',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/ground_track_field',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/harbor',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/industrial_area',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/intersection',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/island',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/lake',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/meadow',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/medium_residential',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/mobile_home_park',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/mountain',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/overpass',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/palace',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/parking_lot',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/railway',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/railway_station',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/rectangular_farmland',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/river',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/roundabout',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/runway',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/sea_ice',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/ship',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/snowberg',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/sparse_residential',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/stadium',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/storage_tank',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/tennis_court',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/terrace',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/thermal_power_station',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/wetland']

# %% [markdown]
# ## Reading and displaying imagery

# %%
from imageio import imread
import matplotlib.pyplot as plt

# %%
with fs.open('cdi-workshop/imrecog_data/NWPU-RESISC45/test/airplane/airplane_700.jpg', 'rb') as f:
    image = imread(f, 'jpg')
    plt.figure(0, figsize=(10,10))
    plt.imshow(image);

# %%
fs.ls('cdi-workshop/imrecog_data/NWPU-RESISC45/test')
# Out:
# ['cdi-workshop/imrecog_data/NWPU-RESISC45/test/airplane',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/airport',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/baseball_diamond',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/basketball_court',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/beach',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/bridge',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/chaparral',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/church',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/circular_farmland',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/cloud',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/commercial_area',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/dense_residential',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/desert',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/forest',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/freeway',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/golf_course',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/ground_track_field',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/harbor',
#  'cdi-workshop/imrecog_data/NWPU-RESISC45/test/industrial_area']

# %%
names = [f for f in fs.ls('cdi-workshop/imrecog_data/NWPU-RESISC45/test/baseball_diamond') if f.endswith('.jpg')]
names = names[:10]

# %%
fig, ax = plt.subplots(3, 3)
fig.set_figheight(15)
fig.set_figwidth(15)
for i, axi in enumerate(ax.flat):
    with fs.open(names[i], 'rb') as f:
        image = imread(f, 'jpg')
    axi.imshow(image)
    axi.set(xticks=[], yticks=[])

# %% [markdown]
# ## Read Labels

# %%
fs.ls('cdi-workshop/semseg_data/gc/labels')
# Out:
# ['cdi-workshop/semseg_data/gc/labels/labels.txt']

# %%
with fs.open('cdi-workshop/semseg_data/gc/labels/labels.txt', 'rb') as f:
      labels = f.readlines()

labels = [x.strip() for x in labels] 
print(labels)
print(labels[0].decode())
# Out:
# [b'rock', b'sand', b'veg', b'water']
# rock

# %% [markdown]
# ## Read binary data files

# %%
from scipy.io import loadmat

# %%
with fs.open('cdi-workshop/semseg_data/ontario/test/A2014862_geotag_mres.mat') as f:
    dat = loadmat(f)

# %%
dat.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'labels', 'sparse', 'preds', 'class'])
